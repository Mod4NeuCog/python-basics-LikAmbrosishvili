# %%
#Exercise 1

def main():
    membrane = float(-65)
    
    membrane = membrane * 40
    print(membrane)
    
if __name__ == "__main__":
    main()
# Out:
# -2600.0

# %%
#Exercise 2

def main():
   # membrane = 1
    membrane = 1.0
    membrane = membrane * 0.7
    print(membrane)
    
if __name__ == "__main__":
    main


#before multiplying  variable "membrane" to 0.7 the type of the variable was int
#after multiplication variable membrane became float type. 
#it is because 1 is an integer (int) and 0.7 is a float. After multiplying int by float. the answer gets float.


# I changed variable 'membrane''s value from 1 to 1.0 With foat on Jupyter Notebook is a problem, it does not execute

# %%
#Exercise 3 
#file neuron1.py
import sys

spike = sys.argv[1]


if (float(spike) >=-65):
    print(5)
else: 
    print(0)

# %%
#neuron1.py

spike  = input()
membrane = float(spike) * 40
print(membrane)

# %% [markdown]
# ![Screenshot 2023-09-15 at 4.49.48 PM.png](attachment:3d58f06e-7bb4-42e6-98f9-e8afc4920595.png)
