# %%
#Exercise 4

import sys

def Membrane_pot(n):
    membrane = float(n) * 40
    print(membrane)
    Membrane_state(membrane)


def Membrane_state(k):
    if (k>500):
        print("membrane is greater than 500")
    if (k<=500):
        print("membrane is less than or equal to 500")
    else:
        print("what??")
    

def main():
   
    spike = float(input())
    if (float(spike) >=-65):
        print(5)
    else: 
        print(0)

    Membrane_pot(spike)
    
    
if __name__ == "__main__":
    main()
# Out:
#  10
# 5
# 400.0
# membrane is less than or equal to 500

# %%
#Exercise 5

import sys


def main():
   
    weigh = float(input())
    synaptic = 10
    V_membrane_Pot = 2
    
    V_membrane_Pot = V_membrane_Pot + synaptic * weigh
    print(V_membrane_Pot)
    

if __name__ == "__main__":
    main()
# Out:
#  20
# 202.0

# %%
#Exercise 6
def Membrane_pot(n):
    membrane = float(n) * 40
    print("membrane  = " + str(membrane))

    
def Membrane_pot2(n,i, j):
    #here I assign three parameters received from Simulate() 
    V_membrane_Pot = n
    synaptic = i
    weight = j

    #here I calculate membrane potential 
    V_membrane_Pot = V_membrane_Pot + synaptic * weight
    print("membrane 1 = " + str(V_membrane_Pot))
        
    
def Simulate():
    #I have three variables here 
    #I receive  2 of them from the user
    weight = float(input("enter synaptic"))
    synaptic = float(input("enter spike"))
    V_membrane_Pot = 1

  
    Membrane_pot(spike) #I call function 1 (Membrane_pot) passing 'spike' parameter
    Membrane_pot2(V_membrane_Pot, synaptic, weight ) #I call function 2 passing three parameters 
    
def main():
   
    Simulate()  #I am calling Simulate function
    
if __name__ == "__main__":
    main()
# Out:
# enter synaptic 10
# enter spike 2
# membrane  = 400.0
# membrane 1 = 21.0

# %%
import sys
V_membrane_Pot = 1
array = [1 for i in range(0,10)]
for i in range(0,10):
    
    V_membrane_Pot *=  2 
    array[i] = V_membrane_Pot

print(array)
# Out:
# [2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]

# %% [markdown]
# ![Screenshot 2023-09-19 at 4.36.19 PM.png](attachment:1235c0ca-492a-4c7b-aff3-3156dfa54c0e.png)
